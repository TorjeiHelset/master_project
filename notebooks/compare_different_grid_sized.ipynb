# %%
import sys
sys.path.append('../src')

import generate_example_networks as generate
import torch
import loading_json as load
import json

# %%
# First generate network only with N=2
network = generate.compare_grid_size_network(T = 100, N = 2, scheme = 3)

# %%
# for road in network.roads:
#     print(road.left)
#     print(road.right)
#     print(road.periodic)

# %%
# import FV_schemes as fv
# print(fv.Rusanov_Flux_2(torch.tensor(0.03744), torch.tensor(0.3), torch.tensor(2.0)))

# %%
# network.roads[0].rho = torch.tensor([0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3000,
#         0.3000, 0.3000, 0.3, 0.3, 0.3])
# print(network.roads[0].max_dt())

# network.roads[0].rho = torch.tensor([0.03744, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3000,
#         0.3000, 0.3000, 0.3, 0.3, 0.3])
# print(network.roads[0].max_dt())
# print(network.roads[0].gamma[0])

# %%
densities, queues, _, _ = network.solve_cons_law()

# %%
# Write to json file:
densities_loaded = load.convert_from_tensor(densities)
queues_loaded = load.convert_from_tensor(queues)

# %%
with open("../results/comparing_grids_N=2.json", 'w') as fd:
    fd.write(json.dumps([densities_loaded, queues_loaded]))

# %%
times = list(densities[0].keys())
for j, t in enumerate(times):
    print(f"Time = {t}")
    rho_sum = 0
    for i in range(len(densities)):
        rho_sum += torch.sum(densities[i][t][:]) * network.roads[i].max_dens
    print(f"Sum of densities: {rho_sum}")
    print()

    if j > 10000:
        break
# Out:
# Time = 0
# Sum of densities: 45.000003814697266
#
# Time = 0.8999999761581421
# Sum of densities: 45.0
#
# Time = 1.7999999523162842
# Sum of densities: 45.000003814697266
#
# Time = 2.6999998092651367
# Sum of densities: 45.0
#
# Time = 3.5999999046325684
# Sum of densities: 44.999996185302734
#
# Time = 4.5
# Sum of densities: 45.000003814697266
#
# Time = 5.0
# Sum of densities: 45.0
#
# Time = 5.900000095367432
# Sum of densities: 45.00000762939453
#
# Time = 6.800000190734863
# Sum of densities: 45.000003814697266
#
# Time = 7.700000286102295
# Sum of densities: 45.0
#
# Time = 8.600000381469727
# Sum of densities: 45.000003814697266
#
# Time = 9.5
# Sum of densities: 45.0
#
# Time = 10.0
# Sum of densities: 45.000003814697266
#
# Time = 10.899999618530273
# Sum of densities: 45.000003814697266
#
# Time = 11.799999237060547
# Sum of densities: 45.00000762939453
#
# Time = 12.69999885559082
# Sum of densities: 45.000003814697266
#
# Time = 13.599998474121094
# Sum of densities: 45.00000762939453
#
# Time = 14.499998092651367
# Sum of densities: 45.0
#
# Time = 15.39999771118164
# Sum of densities: 44.99999237060547
#
# Time = 16.299997329711914
# Sum of densities: 45.000003814697266
#
# Time = 17.199996948242188
# Sum of densities: 45.000003814697266
#
# Time = 18.09999656677246
# Sum of densities: 44.999996185302734
#
# Time = 18.999996185302734
# Sum of densities: 45.000003814697266
#
# Time = 19.899995803833008
# Sum of densities: 44.999996185302734
#
# Time = 20.79999542236328
# Sum of densities: 45.0
#
# Time = 21.699995040893555
# Sum of densities: 45.0
#
# Time = 22.599994659423828
# Sum of densities: 45.0
#
# Time = 23.4999942779541
# Sum of densities: 45.0
#
# Time = 24.399993896484375
# Sum of densities: 45.00000762939453
#
# Time = 25.29999351501465
# Sum of densities: 45.0
#
# Time = 26.199993133544922
# Sum of densities: 45.00000762939453
#
# Time = 27.099992752075195
# Sum of densities: 45.000003814697266
#
# Time = 27.99999237060547
# Sum of densities: 45.0
#
# Time = 28.899991989135742
# Sum of densities: 45.000003814697266
#
# Time = 29.799991607666016
# Sum of densities: 45.0
#
# Time = 30.69999122619629
# Sum of densities: 45.0
#
# Time = 31.599990844726562
# Sum of densities: 45.00000762939453
#
# Time = 32.49999237060547
# Sum of densities: 45.000003814697266
#
# Time = 33.399993896484375
# Sum of densities: 45.00000762939453
#
# Time = 34.29999542236328
# Sum of densities: 45.0000114440918
#
# Time = 35.19999694824219
# Sum of densities: 45.0000114440918
#
# Time = 36.099998474121094
# Sum of densities: 45.0
#
# Time = 37.0
# Sum of densities: 45.0000114440918
#
# Time = 37.900001525878906
# Sum of densities: 45.000003814697266
#
# Time = 38.80000305175781
# Sum of densities: 45.0000114440918
#
# Time = 39.70000457763672
# Sum of densities: 45.000003814697266
#
# Time = 40.600006103515625
# Sum of densities: 45.00000762939453
#
# Time = 41.50000762939453
# Sum of densities: 45.00000762939453
#
# Time = 42.40000915527344
# Sum of densities: 45.00000762939453
#
# Time = 43.300010681152344
# Sum of densities: 45.000003814697266
#
# Time = 44.20001220703125
# Sum of densities: 45.0
#
# Time = 45.100013732910156
# Sum of densities: 45.000003814697266
#
# Time = 46.00001525878906
# Sum of densities: 45.00000762939453
#
# Time = 46.90001678466797
# Sum of densities: 45.000003814697266
#
# Time = 47.800018310546875
# Sum of densities: 45.00000762939453
#
# Time = 48.70001983642578
# Sum of densities: 45.0000114440918
#
# Time = 49.60002136230469
# Sum of densities: 45.00000762939453
#
# Time = 50.0
# Sum of densities: 45.0
#
# Time = 50.900001525878906
# Sum of densities: 45.00000762939453
#
# Time = 51.80000305175781
# Sum of densities: 45.00000762939453
#
# Time = 52.70000457763672
# Sum of densities: 45.00000762939453
#
# Time = 53.600006103515625
# Sum of densities: 45.00000762939453
#
# Time = 54.50000762939453
# Sum of densities: 45.000003814697266
#
# Time = 55.0
# Sum of densities: 45.00000762939453
#
# Time = 55.900001525878906
# Sum of densities: 45.00000762939453
#
# Time = 56.80000305175781
# Sum of densities: 45.00000762939453
#
# Time = 57.70000457763672
# Sum of densities: 45.00000762939453
#
# Time = 58.600006103515625
# Sum of densities: 45.00000762939453
#
# Time = 59.50000762939453
# Sum of densities: 45.000003814697266
#
# Time = 60.0
# Sum of densities: 45.00000762939453
#
# Time = 60.900001525878906
# Sum of densities: 45.000003814697266
#
# Time = 61.80000305175781
# Sum of densities: 45.000003814697266
#
# Time = 62.70000457763672
# Sum of densities: 45.000003814697266
#
# Time = 63.600006103515625
# Sum of densities: 45.00000762939453
#
# Time = 64.50000762939453
# Sum of densities: 45.000003814697266
#
# Time = 65.0
# Sum of densities: 45.000003814697266
#
# Time = 65.9000015258789
# Sum of densities: 45.000003814697266
#
# Time = 66.80000305175781
# Sum of densities: 45.00000762939453
#
# Time = 67.70000457763672
# Sum of densities: 45.000003814697266
#
# Time = 68.60000610351562
# Sum of densities: 45.000003814697266
#
# Time = 69.50000762939453
# Sum of densities: 45.0
#
# Time = 70.0
# Sum of densities: 45.000003814697266
#
# Time = 70.9000015258789
# Sum of densities: 45.00000762939453
#
# Time = 71.80000305175781
# Sum of densities: 45.000003814697266
#
# Time = 72.70000457763672
# Sum of densities: 45.000003814697266
#
# Time = 73.60000610351562
# Sum of densities: 45.000003814697266
#
# Time = 74.50000762939453
# Sum of densities: 45.0
#
# Time = 75.0
# Sum of densities: 45.000003814697266
#
# Time = 75.9000015258789
# Sum of densities: 45.000003814697266
#
# Time = 76.80000305175781
# Sum of densities: 45.000003814697266
#
# Time = 77.70000457763672
# Sum of densities: 45.000003814697266
#
# Time = 78.60000610351562
# Sum of densities: 45.00000762939453
#
# Time = 79.50000762939453
# Sum of densities: 45.000003814697266
#
# Time = 80.0
# Sum of densities: 45.00000762939453
#
# Time = 80.9000015258789
# Sum of densities: 45.000003814697266
#
# Time = 81.80000305175781
# Sum of densities: 45.0
#
# Time = 82.70000457763672
# Sum of densities: 45.000003814697266
#
# Time = 83.60000610351562
# Sum of densities: 45.0
#
# Time = 84.50000762939453
# Sum of densities: 45.000003814697266
#
# Time = 85.40000915527344
# Sum of densities: 45.000003814697266
#
# Time = 86.30001068115234
# Sum of densities: 45.00000762939453
#
# Time = 87.20001220703125
# Sum of densities: 45.000003814697266
#
# Time = 88.10001373291016
# Sum of densities: 45.0
#
# Time = 89.00001525878906
# Sum of densities: 45.000003814697266
#
# Time = 89.90001678466797
# Sum of densities: 45.000003814697266
#
# Time = 90.80001831054688
# Sum of densities: 45.000003814697266
#
# Time = 91.70001983642578
# Sum of densities: 45.00000762939453
#
# Time = 92.60002136230469
# Sum of densities: 45.00000762939453
#
# Time = 93.5000228881836
# Sum of densities: 45.000003814697266
#
# Time = 94.4000244140625
# Sum of densities: 45.00000762939453
#
# Time = 95.3000259399414
# Sum of densities: 45.000003814697266
#
# Time = 96.20002746582031
# Sum of densities: 45.00000762939453
#
# Time = 97.10002899169922
# Sum of densities: 45.00000762939453
#
# Time = 98.00003051757812
# Sum of densities: 45.000003814697266
#
# Time = 98.90003204345703
# Sum of densities: 45.0
#
# Time = 99.80003356933594
# Sum of densities: 45.000003814697266
#
# Time = 100.0
# Sum of densities: 45.000003814697266
