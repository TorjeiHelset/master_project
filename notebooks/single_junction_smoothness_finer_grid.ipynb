# %%
import sys
sys.path.append("../src")
import smoothness as smooth
import numpy as np
import matplotlib.pyplot as plt
import tikzplotlib
import contextlib

# %% [markdown]
# #### N = 6

# %%
T = 150
N = 6
speed_limits = [40.0, 40.0]
controls = [[], []]
cycle = [60.0, 60.0]

increment =  np.linspace(-1, 1, 21)

# %%
with contextlib.redirect_stdout(None):
    objectives_1_two, gradients_1_two = smooth.single_junction_smooth(T, N, speed_limits, controls, cycle, increment, 0, 0)

# %%
delta_inc = increment[1] - increment[0]

# Speed 1:
for inc, speed_obj, grad in zip(increment, objectives_1_two, gradients_1_two):
    plt.plot([40 + inc - delta_inc/2, 40 + inc + delta_inc/2], [speed_obj.detach() - grad * delta_inc / 2, speed_obj.detach() + grad * delta_inc / 2], '--r')
plt.plot(40+increment, [o.detach() for o in objectives_1_two], '*')

tikzplotlib.save("../figurer/single_junction_bus_delay_01speed_N=6.tex")

# %% [markdown]
# #### N = 12

# %%
T = 150
N = 12
speed_limits = [40.0, 40.0]
controls = [[], []]
cycle = [60.0, 60.0]

increment =  np.linspace(-1, 1, 21)

# %%
with contextlib.redirect_stdout(None):
    objectives_1_two_2, gradients_1_two_2 = smooth.single_junction_smooth(T, N, speed_limits, controls, cycle, increment, 0, 0)

# %%
delta_inc = increment[1] - increment[0]

# Speed 1:
for inc, speed_obj, grad in zip(increment, objectives_1_two_2, gradients_1_two_2):
    plt.plot([40 + inc - delta_inc/2, 40 + inc + delta_inc/2], [speed_obj.detach() - grad * delta_inc / 2, speed_obj.detach() + grad * delta_inc / 2], '--r')
plt.plot(40+increment, [o.detach() for o in objectives_1_two_2], '*')

tikzplotlib.save("../figurer/single_junction_bus_delay_01speed_N=12.tex")

# %% [markdown]
# #### N = 24

# %%
T = 150
N = 24
speed_limits = [40.0, 40.0]
controls = [[], []]
cycle = [60.0, 60.0]

increment =  np.linspace(-1, 1, 21)

# %%
with contextlib.redirect_stdout(None):
    objectives_1_two_3, gradients_1_two_3 = smooth.single_junction_smooth(T, N, speed_limits, controls, cycle, increment, 0, 0)

# %%
delta_inc = increment[1] - increment[0]

# Speed 1:
for inc, speed_obj, grad in zip(increment, objectives_1_two_3, gradients_1_two_3):
    plt.plot([40 + inc - delta_inc/2, 40 + inc + delta_inc/2], [speed_obj.detach() - grad * delta_inc / 2, speed_obj.detach() + grad * delta_inc / 2], '--r')
plt.plot(40+increment, [o.detach() for o in objectives_1_two_3], '*')

tikzplotlib.save("../figurer/single_junction_bus_delay_01speed_N=24.tex")

# %% [markdown]
# #### N = 48

# %%
T = 150
N = 48
speed_limits = [40.0, 40.0]
controls = [[], []]
cycle = [60.0, 60.0]

increment =  np.linspace(-1, 1, 21)

# %%
with contextlib.redirect_stdout(None):
    objectives_1_two_4, gradients_1_two_4 = smooth.single_junction_smooth(T, N, speed_limits, controls, cycle, increment, 0, 0)

# %%
delta_inc = increment[1] - increment[0]

# Speed 1:
for inc, speed_obj, grad in zip(increment, objectives_1_two_4, gradients_1_two_4):
    plt.plot([40 + inc - delta_inc/2, 40 + inc + delta_inc/2], [speed_obj.detach() - grad * delta_inc / 2, speed_obj.detach() + grad * delta_inc / 2], '--r')
plt.plot(40+increment, [o.detach() for o in objectives_1_two_4], '*')

tikzplotlib.save("../figurer/single_junction_bus_delay_01speed_N=48.tex")

# %% [markdown]
# #### N = 80

# %%
T = 150
N = 80
speed_limits = [40.0, 40.0]
controls = [[], []]
cycle = [60.0, 60.0]

increment =  np.linspace(-1, 1, 21)

# %%
with contextlib.redirect_stdout(None):
    objectives_1_two_4, gradients_1_two_4 = smooth.single_junction_smooth(T, N, speed_limits, controls, cycle, increment, 0, 0)

# %%
delta_inc = increment[1] - increment[0]

# Speed 1:
for inc, speed_obj, grad in zip(increment, objectives_1_two_4, gradients_1_two_4):
    plt.plot([40 + inc - delta_inc/2, 40 + inc + delta_inc/2], [speed_obj.detach() - grad * delta_inc / 2, speed_obj.detach() + grad * delta_inc / 2], '--r')
plt.plot(40+increment, [o.detach() for o in objectives_1_two_4], '*')

tikzplotlib.save("../figurer/single_junction_bus_delay_01speed_N=80.tex")
